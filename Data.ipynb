# %% [markdown]
# # Data

# %% [markdown]
# ## Here I have used location data from Foursquare. I retrieved location data of the restuarants of Kathmandu that serves mainly Chinese food. These data will be enough to provide the solution to the given problem.

# %% [markdown]
# ### Here I imported necessary libraries.

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::openssl-1.1.1d-h1de35cc_2
#   - anaconda::openssl-1.1.1d-h1de35cc_2, defaults::ca-certificates-2019.8.28-0
#   - anaconda::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-h1de35cc_2
#   - defaults::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-h1de35ccdone
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# Warning: 4 possible package resolutions (only showing differing packages):
#   - anaconda::ca-certificates-2019.8.28-0, anaconda::openssl-1.1.1d-h1de35cc_2
#   - anaconda::openssl-1.1.1d-h1de35cc_2, defaults::ca-certificates-2019.8.28-0
#   - anaconda::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-h1de35cc_2
#   - defaults::ca-certificates-2019.8.28-0, defaults::openssl-1.1.1d-h1de35ccdone
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### I provided my Foursquare credentials.

# %%
CLIENT_ID = 'IBOUQLHOHPHNQO0PK2D0UTM2WDZALL5V3Y233CMZJDKBVD5U' # your Foursquare ID
CLIENT_SECRET = 'SWU5Y51BPUDKKI5NWCVR31OVDBNZUECAJHKAC5XPK3ZWWJTW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: IBOUQLHOHPHNQO0PK2D0UTM2WDZALL5V3Y233CMZJDKBVD5U
# CLIENT_SECRET:SWU5Y51BPUDKKI5NWCVR31OVDBNZUECAJHKAC5XPK3ZWWJTW

# %% [markdown]
# ### The goal of the project is to find the restaurants that serves mainly Chinese food in Kathmandu. The conversion of address of place to latitude and longitude will provide specific data.

# %%
address = 'Kathmandu, Nepal'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 27.708796 85.320244

# %% [markdown]
# ### Here, searching Chinese food serving restaurants in Kathmandu

# %%
search_query = 'Chinese food'
radius = 1000
print(search_query + ' .... OK!')
# Out:
# Chinese food .... OK!

# %% [markdown]
# ### Defining the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=IBOUQLHOHPHNQO0PK2D0UTM2WDZALL5V3Y233CMZJDKBVD5U&client_secret=SWU5Y51BPUDKKI5NWCVR31OVDBNZUECAJHKAC5XPK3ZWWJTW&ll=27.708796,85.320244&v=20180605&query=Chinese food&radius=1000&limit=100'

# %% [markdown]
# ### Sending the get request and examining the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e14633547b43d00242ee22e'},
#  'response': {'venues': [{'id': '5a5615c21b0ea539aaf508db',
#     'name': 'Nepal Go - Special Chinese Food',
#     'location': {'address': 'Jyatha',
#      'lat': 27.712069,
#      'lng': 85.31205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.712069,
#        'lng': 85.31205}],
#      'distance': 885,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'Kathmandu',
#      'state': 'Central Development Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Jyatha', 'Kathmandu 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '54532e2a498e92ceba7d6da4',
#     'name': 'R.S. Chinese Food Services',
#     'location': {'address': 'Naxal',
#      'crossStreet': 'Bhagawati Bahal',
#      'lat': 27.713106155395508,
#      'lng': 85.32889556884766,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.713106155395508,
#        'lng': 85.32889556884766}],
#      'distance': 978,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['Naxal (Bhagawati Bahal)', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '516e7605e4b0e7ecec8f8751',
#     'name': 'Chinese Stick Food Cafe',
#     'location': {'address': 'Naxal',
#      'crossStreet': 'Across Naxal Bhagwati Mandir',
#      'lat': 27.71302334693707,
#      'lng': 85.32878340236519,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71302334693707,
#        'lng': 85.32878340236519}],
#      'distance': 964,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Naxal (Across Naxal Bhagwati Mandir)',
#       'काठमाडौं',
#       'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c7941735',
#       'name': 'Snack Place',
#       'pluralName': 'Snack Places',
#       'shortName': 'Snacks',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '50e3f741e4b0b92a498527f7',
#     'name': 'Chinese Friendship Restaurant',
#     'location': {'address': 'Durbarmarg',
#      'lat': 27.71251600723441,
#      'lng': 85.31800636830438,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71251600723441,
#        'lng': 85.31800636830438}],
#      'distance': 469,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Durbarmarg', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '520c59e611d23d6d7c3ccc01',
#     'name': 'Chinese Embassy',
#     'location': {'address': 'Hattisar',
#      'lat': 27.712415,
#      'lng': 85.322122,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.712415,
#        'lng': 85.322122}],
#      'distance': 443,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['Hattisar', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d12c951735',
#       'name': 'Embassy / Consulate',
#       'pluralName': 'Embassies / Consulates',
#       'shortName': 'Embassy',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/embassy_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4fa64fece4b0cbe2e0a9467e',
#     'name': 'Chinese charming',
#     'location': {'address': 'Kathmandu Mall',
#      'lat': 27.705028265741344,
#      'lng': 85.31625963238847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.705028265741344,
#        'lng': 85.31625963238847}],
#      'distance': 574,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['Kathmandu Mall', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '537f2e7a498ebe93301f6199',
#     'name': 'Kathmandu Chinese Mee',
#     'location': {'address': 'Thamel',
#      'lat': 27.71287725424161,
#      'lng': 85.31143814965614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71287725424161,
#        'lng': 85.31143814965614}],
#      'distance': 979,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Thamel', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '54198c99498e9b142b5934e1',
#     'name': 'Chinese Restaurant',
#     'location': {'address': 'Jyatha',
#      'lat': 27.711600972082508,
#      'lng': 85.31222577170445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711600972082508,
#        'lng': 85.31222577170445}],
#      'distance': 849,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Jyatha', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5284913c11d23b71240eaa0a',
#     'name': 'Garden Park Fast Food & Restaurant',
#     'location': {'lat': 27.70981263515604,
#      'lng': 85.31934919668629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70981263515604,
#        'lng': 85.31934919668629}],
#      'distance': 143,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5853819803cf255eb30375e1',
#     'name': 'Chinese noodle shop / 中华面馆',
#     'location': {'lat': 27.712881,
#      'lng': 85.3114,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.712881,
#        'lng': 85.3114}],
#      'distance': 983,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '530359b6498ebaab58ded635',
#     'name': 'Chinese Sumai Cafe',
#     'location': {'lat': 27.70605859814724,
#      'lng': 85.30970635102462,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70605859814724,
#        'lng': 85.30970635102462}],
#      'distance': 1082,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '52c9601a498eaad42cd93056',
#     'name': 'Zhongguo Flavour Chinese Restaurant',
#     'location': {'lat': 27.710021206217206,
#      'lng': 85.31914222153037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.710021206217206,
#        'lng': 85.31914222153037}],
#      'distance': 174,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5d51387c941303000822e8a3',
#     'name': 'Nepal-Chinese Educational & Cultural Center',
#     'location': {'address': 'Putalisadak',
#      'lat': 27.707095,
#      'lng': 85.3231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.707095,
#        'lng': 85.3231}],
#      'distance': 339,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Putalisadak', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a48',
#       'name': 'Language School',
#       'pluralName': 'Language Schools',
#       'shortName': 'Language School',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4f683fc7e4b0d535a5cc886d',
#     'name': 'Best Fast Food Restaurant',
#     'location': {'address': 'Putalisadak, Kathmandu 44600',
#      'lat': 27.70623546380231,
#      'lng': 85.32308471106882,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70623546380231,
#        'lng': 85.32308471106882}],
#      'distance': 399,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Putalisadak, Kathmandu 44600',
#       'काठमाडौं 44600',
#       'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '50c709b7e4b0b353eb63fcf5',
#     'name': 'Chito Mitho Stick Fast Food',
#     'location': {'address': 'Naxal Road',
#      'crossStreet': 'Next To Everest Momo',
#      'lat': 27.70976263468375,
#      'lng': 85.32809191882417,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70976263468375,
#        'lng': 85.32809191882417}],
#      'distance': 780,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Naxal Road (Next To Everest Momo)',
#       'काठमाडौं',
#       'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d108941735',
#       'name': 'Dumpling Restaurant',
#       'pluralName': 'Dumpling Restaurants',
#       'shortName': 'Dumplings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '59ec94b1a6031c48a4034f70',
#     'name': 'Food Junction',
#     'location': {'address': 'Kamaladi',
#      'lat': 27.707962,
#      'lng': 85.31798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.707962,
#        'lng': 85.31798}],
#      'distance': 241,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'Kathmandu',
#      'state': 'Central Development Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Kamaladi', 'Kathmandu 44600', 'नेपाल']},
#     'categories': [{'id': '56aa371be4b08b9a8d57350b',
#       'name': 'Food Stand',
#       'pluralName': 'Food Stands',
#       'shortName': 'Food Stand',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/movingtarget_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4eeb13b49a52f269b6ca4bea',
#     'name': 'Nanglo Chinese Room',
#     'location': {'lat': 27.71089963221201,
#      'lng': 85.31735008679068,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71089963221201,
#        'lng': 85.31735008679068}],
#      'distance': 369,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '51bbf7e2498ed05ef8d6adc0',
#     'name': 'Wifi Food Cafe',
#     'location': {'lat': 27.707103729248047,
#      'lng': 85.3228530883789,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.707103729248047,
#        'lng': 85.3228530883789}],
#      'distance': 318,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '57398e69498e9e5d0c833d82',
#     'name': 'Centre Point Food Cafe',
#     'location': {'lat': 27.705458,
#      'lng': 85.3227,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.705458,
#        'lng': 85.3227}],
#      'distance': 443,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '539ee1ae498e35589f8bc01d',
#     'name': "Brother's Fast Food",
#     'location': {'address': 'Dhobidhara',
#      'lat': 27.707592264943493,
#      'lng': 85.32332700588353,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.707592264943493,
#        'lng': 85.32332700588353}],
#      'distance': 332,
#      'postalCode': '00977',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Dhobidhara', 'काठमाडौं 00977', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4f6701e9e4b03a7ce336627f',
#     'name': 'Jhakas Fast Food',
#     'location': {'lat': 27.711315155029297,
#      'lng': 85.32279205322266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711315155029297,
#        'lng': 85.32279205322266}],
#      'distance': 376,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '51729f17e4b0cb9cb448aae4',
#     'name': 'Royal Dragon Chinese Restaurant',
#     'location': {'address': 'Durbar Marg',
#      'lat': 27.711903666931537,
#      'lng': 85.31747124704793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711903666931537,
#        'lng': 85.31747124704793}],
#      'distance': 440,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['Durbar Marg', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '555c77ac498e63ff961a4613',
#     'name': 'Delicious Food Station',
#     'location': {'lat': 27.709014,
#      'lng': 85.324688,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.709014,
#        'lng': 85.324688}],
#      'distance': 438,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5c91e9c33e6741002cfa2b39',
#     'name': 'Classic Rock Coffee/Food/Bar',
#     'location': {'lat': 27.710411,
#      'lng': 85.310772,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.710411,
#        'lng': 85.310772}],
#      'distance': 950,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4eda0df1b6344371f66bbabd',
#     'name': 'Bok Choy Chinese, Continental & Italian Cuisine',
#     'location': {'address': 'Share Market Complex, Putalisadak',
#      'lat': 27.704107279402937,
#      'lng': 85.32267583613205,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.704107279402937,
#        'lng': 85.32267583613205}],
#      'distance': 574,
#      'postalCode': '00977',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Share Market Complex, Putalisadak',
#       'काठमाडौं 00977',
#       'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4fa27758e4b0b4ed787228fe',
#     'name': 'Kathmandu Fast Food & Bakery Cafe',
#     'location': {'lat': 27.709365681994274,
#      'lng': 85.32723890881611,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.709365681994274,
#        'lng': 85.32723890881611}],
#      'distance': 692,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5593a39f498e4e910f31e76c',
#     'name': 'New Acharya Fast Food',
#     'location': {'lat': 27.709595,
#      'lng': 85.327812,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.709595,
#        'lng': 85.327812}],
#      'distance': 751,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '567e6f09498ed310e2ae3ca1',
#     'name': "3Brother's Fast Food & Restaurant",
#     'location': {'address': 'Bagbazar-31',
#      'lat': 27.70303222518477,
#      'lng': 85.3204496855686,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70303222518477,
#        'lng': 85.3204496855686}],
#      'distance': 641,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Bagbazar-31', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5930fca0396de0394a28f9f0',
#     'name': 'Food Court (City Center)',
#     'location': {'address': 'City Center',
#      'crossStreet': 'Kamalpokhari',
#      'lat': 27.709657,
#      'lng': 85.326677,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.709657,
#        'lng': 85.326677}],
#      'distance': 641,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['City Center (Kamalpokhari)', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d120951735',
#       'name': 'Food Court',
#       'pluralName': 'Food Courts',
#       'shortName': 'Food Court',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '52ee132f498e5dcea7dee6d7',
#     'name': 'Dibya Ratna Terai Food Court',
#     'location': {'lat': 27.704044,
#      'lng': 85.322573,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.704044,
#        'lng': 85.322573}],
#      'distance': 576,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '533ecb7a498ee15d1b17dd91',
#     'name': 'the hygienic panipuri in town & fast food',
#     'location': {'lat': 27.70484269515406,
#      'lng': 85.32540161123605,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70484269515406,
#        'lng': 85.32540161123605}],
#      'distance': 672,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '539aa2db498e718f8995e8d6',
#     'name': 'kwality food cafe',
#     'location': {'lat': 27.705716583742433,
#      'lng': 85.32684520739527,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.705716583742433,
#        'lng': 85.32684520739527}],
#      'distance': 735,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '56768fa2498e41010315de03',
#     'name': 'Shafqat Halal Food Restaurant',
#     'location': {'lat': 27.71345249806686,
#      'lng': 85.31023844865867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71345249806686,
#        'lng': 85.31023844865867}],
#      'distance': 1114,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '52e81612bcbc57f1066b79ff',
#       'name': 'Halal Restaurant',
#       'pluralName': 'Halal Restaurants',
#       'shortName': 'Halal',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/halal_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5ad9b87f1cf2e1494231b434',
#     'name': 'Food Truck',
#     'location': {'lat': 27.71598160186668,
#      'lng': 85.32520980188163,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71598160186668,
#        'lng': 85.32520980188163}],
#      'distance': 937,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'Kathmandu',
#      'state': 'Central Development Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Kathmandu 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '53592917498e7027ec6240dd',
#     'name': 'Kantipur Fast Food',
#     'location': {'lat': 27.713152019172945,
#      'lng': 85.31280638325718,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.713152019172945,
#        'lng': 85.31280638325718}],
#      'distance': 878,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '50921fd8498eeb726306d104',
#     'name': 'Kwality Food Cafe',
#     'location': {'address': 'Khichapokhari',
#      'lat': 27.703622187888193,
#      'lng': 85.31117055753195,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.703622187888193,
#        'lng': 85.31117055753195}],
#      'distance': 1063,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Khichapokhari', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '55096ccf498e9c08e09feede',
#     'name': 'Little Kathmandu Stick Food',
#     'location': {'address': 'New Road',
#      'lat': 27.70269775390625,
#      'lng': 85.31547546386719,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.70269775390625,
#        'lng': 85.31547546386719}],
#      'distance': 825,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['New Road', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '538d8102498e2e5d44d78282',
#     'name': 'Fast Food & Newari Kitchen',
#     'location': {'address': 'Bhagawati Marg',
#      'crossStreet': 'BTWN Thirbum Marg & Sama Marg',
#      'lat': 27.713092,
#      'lng': 85.327296,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.713092,
#        'lng': 85.327296}],
#      'distance': 843,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Bhagawati Marg (BTWN Thirbum Marg & Sama Marg)',
#       'काठमाडौं 44600',
#       'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4f755caee4b05b70741d2a56',
#     'name': 'Kwality fast food (KFC)',
#     'location': {'lat': 27.705658748911034,
#      'lng': 85.32852094249017,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.705658748911034,
#        'lng': 85.32852094249017}],
#      'distance': 887,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '52a06d2311d25a833f1457ac',
#     'name': 'Delicious Food Cafe & Cushion Bar',
#     'location': {'lat': 27.710447125023833,
#      'lng': 85.31077674032585,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.710447125023833,
#        'lng': 85.31077674032585}],
#      'distance': 950,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5c5bcd41c21cb1002cb6bfbe',
#     'name': 'Green Himalaya Coffee & Fast Food',
#     'location': {'address': 'Thamel',
#      'lat': 27.711882,
#      'lng': 85.31284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711882,
#        'lng': 85.31284}],
#      'distance': 806,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'Kathmandu',
#      'state': 'Central Development Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Thamel', 'Kathmandu 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5230677211d22f9e9d7941bf',
#     'name': 'Kylin Chinese restaurant',
#     'location': {'lat': 27.713411,
#      'lng': 85.312251,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.713411,
#        'lng': 85.312251}],
#      'distance': 940,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5ad999eb56c89f7f7a2eab01',
#     'name': 'Namaste Fast Food',
#     'location': {'address': 'Thamel',
#      'lat': 27.714403,
#      'lng': 85.313194,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.714403,
#        'lng': 85.313194}],
#      'distance': 933,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'Kathmandu',
#      'state': 'Central Development Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Thamel', 'Kathmandu 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5487f5aa498ef11b79747e1b',
#     'name': 'The Mix Food land',
#     'location': {'address': 'Jp Road',
#      'crossStreet': 'Chaskibari',
#      'lat': 27.711704646436754,
#      'lng': 85.3104485571541,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711704646436754,
#        'lng': 85.3104485571541}],
#      'distance': 1018,
#      'cc': 'NP',
#      'city': 'Thamel',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Jp Road (Chaskibari)', 'Thamel', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '58283da9da08cb6d4778d234',
#     'name': 'Foodies',
#     'location': {'lat': 27.710203,
#      'lng': 85.322975,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.710203,
#        'lng': 85.322975}],
#      'distance': 311,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['काठमाडौं 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d108941735',
#       'name': 'Dumpling Restaurant',
#       'pluralName': 'Dumpling Restaurants',
#       'shortName': 'Dumplings',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '5b98b968c365880039150ec5',
#     'name': 'Sunflower Fast Food Restaurant',
#     'location': {'address': 'J P Marg',
#      'lat': 27.711776,
#      'lng': 85.309984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.711776,
#        'lng': 85.309984}],
#      'distance': 1064,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'カトマンズ',
#      'state': 'バグマティ',
#      'country': 'नेपाल',
#      'formattedAddress': ['J P Marg', 'カトマンズ 44600', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '519e24d4498e5da24bf29bcd',
#     'name': 'New Foodland',
#     'location': {'lat': 27.71095917989207,
#      'lng': 85.3221710480383,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71095917989207,
#        'lng': 85.3221710480383}],
#      'distance': 306,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '58283d229e41df0d62f0ffeb',
#     'name': "Foodie's",
#     'location': {'lat': 27.71034,
#      'lng': 85.32314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.71034,
#        'lng': 85.32314}],
#      'distance': 333,
#      'postalCode': '44600',
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['काठमाडौं 44600', 'नेपाल']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '50c3151ae4b009e3bbb65e93',
#     'name': 'Deurali Food Land',
#     'location': {'lat': 27.712018935838167,
#      'lng': 85.30903482251297,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.712018935838167,
#        'lng': 85.30903482251297}],
#      'distance': 1161,
#      'cc': 'NP',
#      'country': 'नेपाल',
#      'formattedAddress': ['नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d16e941735',
#       'name': 'Fast Food Restaurant',
#       'pluralName': 'Fast Food Restaurants',
#       'shortName': 'Fast Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False},
#    {'id': '4edf431077c8c05f362e2317',
#     'name': 'Vootoo',
#     'location': {'address': 'Ananda Bhawan',
#      'crossStreet': 'Lazimpat',
#      'lat': 27.718458601332777,
#      'lng': 85.31767682089165,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 27.718458601332777,
#        'lng': 85.31767682089165}],
#      'distance': 1104,
#      'cc': 'NP',
#      'city': 'काठमाडौं',
#      'state': 'Central Region',
#      'country': 'नेपाल',
#      'formattedAddress': ['Ananda Bhawan (Lazimpat)', 'काठमाडौं', 'नेपाल']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1578394404',
#     'hasPerk': False}]}}

# %% [markdown]
# ### We get dataframe listed with eateries serving Chinese food and its metadata.

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                             name  \
# 0  5a5615c21b0ea539aaf508db  Nepal Go - Special Chinese Food
# 1  54532e2a498e92ceba7d6da4       R.S. Chinese Food Services
# 2  516e7605e4b0e7ecec8f8751          Chinese Stick Food Cafe
# 3  50e3f741e4b0b92a498527f7    Chinese Friendship Restaurant
# 4  520c59e611d23d6d7c3ccc01                  Chinese Embassy
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1578394404    False
# 1  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1578394404    False
# 2  [{'id': '4bf58dd8d48988d1c7941735', 'name': 'S...  v-1578394404    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1578394404    False
# 4  [{'id': '4bf58dd8d48988d12c951735', 'name': 'E...  v-1578394404    False
#
#   location.address  location.lat  location.lng  \
# 0           Jyatha     27.712069     85.312050
# 1            Naxal     27.713106     85.328896
# 2            Naxal     27.713023     85.328783
# 3       Durbarmarg     27.712516     85.318006
# 4         Hattisar     27.712415     85.322122
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 27.712069, 'lng':...                885
# 1  [{'label': 'display', 'lat': 27.71310615539550...                978
# 2  [{'label': 'display', 'lat': 27.71302334693707...                964
# 3  [{'label': 'display', 'lat': 27.71251600723441...                469
# 4  [{'label': 'display', 'lat': 27.712415, 'lng':...                443
#
#   location.postalCode location.cc location.city              location.state  \
# 0               44600          NP     Kathmandu  Central Development Region
# 1                 NaN          NP           NaN                         NaN
# 2                 NaN          NP      काठमाडौं              Central Region
# 3                 NaN          NP      काठमाडौं              Central Region
# 4                 NaN          NP           NaN                         NaN
#
#   location.country                          location.formattedAddress  \
# 0            नेपाल                   [Jyatha, Kathmandu 44600, नेपाल]
# 1            नेपाल                   [Naxal (Bhagawati Bahal), नेपाल]
# 2            नेपाल  [Naxal (Across Naxal Bhagwati Mandir), काठमाडौ...
# 3            नेपाल                      [Durbarmarg, काठमाडौं, नेपाल]
# 4            नेपाल                                  [Hattisar, नेपाल]
#
#            location.crossStreet
# 0                           NaN
# 1               Bhagawati Bahal
# 2  Across Naxal Bhagwati Mandir
# 3                           NaN
# 4                           NaN

# %% [markdown]
# ### Essential information is selected and filtered dataframe is created.

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                name            categories  \
# 0                   Nepal Go - Special Chinese Food    Chinese Restaurant
# 1                        R.S. Chinese Food Services                  Café
# 2                           Chinese Stick Food Cafe           Snack Place
# 3                     Chinese Friendship Restaurant    Chinese Restaurant
# 4                                   Chinese Embassy   Embassy / Consulate
# 5                                  Chinese charming                   Spa
# 6                             Kathmandu Chinese Mee    Chinese Restaurant
# 7                                Chinese Restaurant      Asian Restaurant
# 8                Garden Park Fast Food & Restaurant  Fast Food Restaurant
# 9                        Chinese noodle shop / 中华面馆      Theme Restaurant
# 10                               Chinese Sumai Cafe      Asian Restaurant
# 11              Zhongguo Flavour Chinese Restaurant    Chinese Restaurant
# 12      Nepal-Chinese Educational & Cultural Center       Language School
# 13                        Best Fast Food Restaurant  Fast Food Restaurant
# 14                      Chito Mitho Stick Fast Food   Dumpling Restaurant
# 15                                    Food Junction            Food Stand
# 16                              Nanglo Chinese Room    Chinese Restaurant
# 17                                   Wifi Food Cafe            Restaurant
# 18                           Centre Point Food Cafe        Breakfast Spot
# 19                              Brother's Fast Food            Restaurant
# 20                                 Jhakas Fast Food      Asian Restaurant
# 21                  Royal Dragon Chinese Restaurant    Chinese Restaurant
# 22                           Delicious Food Station  Fast Food Restaurant
# 23                     Classic Rock Coffee/Food/Bar                   Bar
# 24  Bok Choy Chinese, Continental & Italian Cuisine    Chinese Restaurant
# 25                Kathmandu Fast Food & Bakery Cafe  Fast Food Restaurant
# 26                            New Acharya Fast Food            Food Court
# 27                3Brother's Fast Food & Restaurant      Asian Restaurant
# 28                         Food Court (City Center)            Food Court
# 29                     Dibya Ratna Terai Food Court  Fast Food Restaurant
# 30        the hygienic panipuri in town & fast food  Fast Food Restaurant
# 31                                kwality food cafe  Fast Food Restaurant
# 32                    Shafqat Halal Food Restaurant      Halal Restaurant
# 33                                       Food Truck            Food Truck
# 34                               Kantipur Fast Food                  None
# 35                                Kwality Food Cafe            Restaurant
# 36                      Little Kathmandu Stick Food  Fast Food Restaurant
# 37                       Fast Food & Newari Kitchen      Asian Restaurant
# 38                          Kwality fast food (KFC)     Indian Restaurant
# 39                Delicious Food Cafe & Cushion Bar     Indian Restaurant
# 40                Green Himalaya Coffee & Fast Food                  Café
# 41                         Kylin Chinese restaurant    Chinese Restaurant
# 42                                Namaste Fast Food  Fast Food Restaurant
# 43                                The Mix Food land      Asian Restaurant
# 44                                          Foodies   Dumpling Restaurant
# 45                   Sunflower Fast Food Restaurant            Restaurant
# 46                                     New Foodland            Restaurant
# 47                                         Foodie's      Theme Restaurant
# 48                                Deurali Food Land  Fast Food Restaurant
# 49                                           Vootoo      Asian Restaurant
#
#                               address        lat        lng  \
# 0                              Jyatha  27.712069  85.312050
# 1                               Naxal  27.713106  85.328896
# 2                               Naxal  27.713023  85.328783
# 3                          Durbarmarg  27.712516  85.318006
# 4                            Hattisar  27.712415  85.322122
# 5                      Kathmandu Mall  27.705028  85.316260
# 6                              Thamel  27.712877  85.311438
# 7                              Jyatha  27.711601  85.312226
# 8                                 NaN  27.709813  85.319349
# 9                                 NaN  27.712881  85.311400
# 10                                NaN  27.706059  85.309706
# 11                                NaN  27.710021  85.319142
# 12                        Putalisadak  27.707095  85.323100
# 13       Putalisadak, Kathmandu 44600  27.706235  85.323085
# 14                         Naxal Road  27.709763  85.328092
# 15                           Kamaladi  27.707962  85.317980
# 16                                NaN  27.710900  85.317350
# 17                                NaN  27.707104  85.322853
# 18                                NaN  27.705458  85.322700
# 19                         Dhobidhara  27.707592  85.323327
# 20                                NaN  27.711315  85.322792
# 21                        Durbar Marg  27.711904  85.317471
# 22                                NaN  27.709014  85.324688
# 23                                NaN  27.710411  85.310772
# 24  Share Market Complex, Putalisadak  27.704107  85.322676
# 25                                NaN  27.709366  85.327239
# 26                                NaN  27.709595  85.327812
# 27                        Bagbazar-31  27.703032  85.320450
# 28                        City Center  27.709657  85.326677
# 29                                NaN  27.704044  85.322573
# 30                                NaN  27.704843  85.325402
# 31                                NaN  27.705717  85.326845
# 32                                NaN  27.713452  85.310238
# 33                                NaN  27.715982  85.325210
# 34                                NaN  27.713152  85.312806
# 35                      Khichapokhari  27.703622  85.311171
# 36                           New Road  27.702698  85.315475
# 37                     Bhagawati Marg  27.713092  85.327296
# 38                                NaN  27.705659  85.328521
# 39                                NaN  27.710447  85.310777
# 40                             Thamel  27.711882  85.312840
# 41                                NaN  27.713411  85.312251
# 42                             Thamel  27.714403  85.313194
# 43                            Jp Road  27.711705  85.310449
# 44                                NaN  27.710203  85.322975
# 45                           J P Marg  27.711776  85.309984
# 46                                NaN  27.710959  85.322171
# 47                                NaN  27.710340  85.323140
# 48                                NaN  27.712019  85.309035
# 49                      Ananda Bhawan  27.718459  85.317677
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 27.712069, 'lng':...       885      44600
# 1   [{'label': 'display', 'lat': 27.71310615539550...       978        NaN
# 2   [{'label': 'display', 'lat': 27.71302334693707...       964        NaN
# 3   [{'label': 'display', 'lat': 27.71251600723441...       469        NaN
# 4   [{'label': 'display', 'lat': 27.712415, 'lng':...       443        NaN
# 5   [{'label': 'display', 'lat': 27.70502826574134...       574        NaN
# 6   [{'label': 'display', 'lat': 27.71287725424161...       979        NaN
# 7   [{'label': 'display', 'lat': 27.71160097208250...       849        NaN
# 8   [{'label': 'display', 'lat': 27.70981263515604...       143        NaN
# 9   [{'label': 'display', 'lat': 27.712881, 'lng':...       983        NaN
# 10  [{'label': 'display', 'lat': 27.70605859814724...      1082        NaN
# 11  [{'label': 'display', 'lat': 27.71002120621720...       174        NaN
# 12  [{'label': 'display', 'lat': 27.707095, 'lng':...       339        NaN
# 13  [{'label': 'display', 'lat': 27.70623546380231...       399      44600
# 14  [{'label': 'display', 'lat': 27.70976263468375...       780        NaN
# 15  [{'label': 'display', 'lat': 27.707962, 'lng':...       241      44600
# 16  [{'label': 'display', 'lat': 27.71089963221201...       369        NaN
# 17  [{'label': 'display', 'lat': 27.70710372924804...       318        NaN
# 18  [{'label': 'display', 'lat': 27.705458, 'lng':...       443        NaN
# 19  [{'label': 'display', 'lat': 27.70759226494349...       332      00977
# 20  [{'label': 'display', 'lat': 27.71131515502929...       376        NaN
# 21  [{'label': 'display', 'lat': 27.71190366693153...       440        NaN
# 22  [{'label': 'display', 'lat': 27.709014, 'lng':...       438        NaN
# 23  [{'label': 'display', 'lat': 27.710411, 'lng':...       950        NaN
# 24  [{'label': 'display', 'lat': 27.70410727940293...       574      00977
# 25  [{'label': 'display', 'lat': 27.70936568199427...       692        NaN
# 26  [{'label': 'display', 'lat': 27.709595, 'lng':...       751        NaN
# 27  [{'label': 'display', 'lat': 27.70303222518477...       641        NaN
# 28  [{'label': 'display', 'lat': 27.709657, 'lng':...       641        NaN
# 29  [{'label': 'display', 'lat': 27.704044, 'lng':...       576        NaN
# 30  [{'label': 'display', 'lat': 27.70484269515406...       672        NaN
# 31  [{'label': 'display', 'lat': 27.70571658374243...       735        NaN
# 32  [{'label': 'display', 'lat': 27.71345249806686...      1114        NaN
# 33  [{'label': 'display', 'lat': 27.71598160186668...       937      44600
# 34  [{'label': 'display', 'lat': 27.71315201917294...       878        NaN
# 35  [{'label': 'display', 'lat': 27.70362218788819...      1063        NaN
# 36  [{'label': 'display', 'lat': 27.70269775390625...       825        NaN
# 37  [{'label': 'display', 'lat': 27.713092, 'lng':...       843      44600
# 38  [{'label': 'display', 'lat': 27.70565874891103...       887        NaN
# 39  [{'label': 'display', 'lat': 27.71044712502383...       950        NaN
# 40  [{'label': 'display', 'lat': 27.711882, 'lng':...       806      44600
# 41  [{'label': 'display', 'lat': 27.713411, 'lng':...       940        NaN
# 42  [{'label': 'display', 'lat': 27.714403, 'lng':...       933      44600
# 43  [{'label': 'display', 'lat': 27.71170464643675...      1018        NaN
# 44  [{'label': 'display', 'lat': 27.710203, 'lng':...       311      44600
# 45  [{'label': 'display', 'lat': 27.711776, 'lng':...      1064      44600
# 46  [{'label': 'display', 'lat': 27.71095917989207...       306        NaN
# 47  [{'label': 'display', 'lat': 27.71034, 'lng': ...       333      44600
# 48  [{'label': 'display', 'lat': 27.71201893583816...      1161        NaN
# 49  [{'label': 'display', 'lat': 27.71845860133277...      1104        NaN
#
#     cc       city                       state country  \
# 0   NP  Kathmandu  Central Development Region   नेपाल
# 1   NP        NaN                         NaN   नेपाल
# 2   NP   काठमाडौं              Central Region   नेपाल
# 3   NP   काठमाडौं              Central Region   नेपाल
# 4   NP        NaN                         NaN   नेपाल
# 5   NP        NaN                         NaN   नेपाल
# 6   NP   काठमाडौं              Central Region   नेपाल
# 7   NP   काठमाडौं              Central Region   नेपाल
# 8   NP        NaN                         NaN   नेपाल
# 9   NP        NaN                         NaN   नेपाल
# 10  NP        NaN                         NaN   नेपाल
# 11  NP        NaN                         NaN   नेपाल
# 12  NP   काठमाडौं              Central Region   नेपाल
# 13  NP   काठमाडौं              Central Region   नेपाल
# 14  NP   काठमाडौं              Central Region   नेपाल
# 15  NP  Kathmandu  Central Development Region   नेपाल
# 16  NP        NaN                         NaN   नेपाल
# 17  NP        NaN                         NaN   नेपाल
# 18  NP        NaN                         NaN   नेपाल
# 19  NP   काठमाडौं              Central Region   नेपाल
# 20  NP        NaN                         NaN   नेपाल
# 21  NP        NaN                         NaN   नेपाल
# 22  NP        NaN                         NaN   नेपाल
# 23  NP   काठमाडौं              Central Region   नेपाल
# 24  NP   काठमाडौं              Central Region   नेपाल
# 25  NP        NaN                         NaN   नेपाल
# 26  NP        NaN                         NaN   नेपाल
# 27  NP   काठमाडौं              Central Region   नेपाल
# 28  NP   काठमाडौं              Central Region   नेपाल
# 29  NP        NaN                         NaN   नेपाल
# 30  NP        NaN                         NaN   नेपाल
# 31  NP        NaN                         NaN   नेपाल
# 32  NP        NaN                         NaN   नेपाल
# 33  NP  Kathmandu  Central Development Region   नेपाल
# 34  NP        NaN                         NaN   नेपाल
# 35  NP   काठमाडौं              Central Region   नेपाल
# 36  NP        NaN                         NaN   नेपाल
# 37  NP   काठमाडौं              Central Region   नेपाल
# 38  NP        NaN                         NaN   नेपाल
# 39  NP        NaN                         NaN   नेपाल
# 40  NP  Kathmandu  Central Development Region   नेपाल
# 41  NP        NaN                         NaN   नेपाल
# 42  NP  Kathmandu  Central Development Region   नेपाल
# 43  NP     Thamel              Central Region   नेपाल
# 44  NP   काठमाडौं              Central Region   नेपाल
# 45  NP      カトマンズ                       バグマティ   नेपाल
# 46  NP        NaN                         NaN   नेपाल
# 47  NP   काठमाडौं              Central Region   नेपाल
# 48  NP        NaN                         NaN   नेपाल
# 49  NP   काठमाडौं              Central Region   नेपाल
#
#                                      formattedAddress  \
# 0                    [Jyatha, Kathmandu 44600, नेपाल]
# 1                    [Naxal (Bhagawati Bahal), नेपाल]
# 2   [Naxal (Across Naxal Bhagwati Mandir), काठमाडौ...
# 3                       [Durbarmarg, काठमाडौं, नेपाल]
# 4                                   [Hattisar, नेपाल]
# 5                             [Kathmandu Mall, नेपाल]
# 6                           [Thamel, काठमाडौं, नेपाल]
# 7                           [Jyatha, काठमाडौं, नेपाल]
# 8                                             [नेपाल]
# 9                                             [नेपाल]
# 10                                            [नेपाल]
# 11                                            [नेपाल]
# 12                     [Putalisadak, काठमाडौं, नेपाल]
# 13  [Putalisadak, Kathmandu 44600, काठमाडौं 44600,...
# 14  [Naxal Road (Next To Everest Momo), काठमाडौं, ...
# 15                 [Kamaladi, Kathmandu 44600, नेपाल]
# 16                                            [नेपाल]
# 17                                            [नेपाल]
# 18                                            [नेपाल]
# 19                [Dhobidhara, काठमाडौं 00977, नेपाल]
# 20                                            [नेपाल]
# 21                               [Durbar Marg, नेपाल]
# 22                                            [नेपाल]
# 23                                  [काठमाडौं, नेपाल]
# 24  [Share Market Complex, Putalisadak, काठमाडौं 0...
# 25                                            [नेपाल]
# 26                                            [नेपाल]
# 27                     [Bagbazar-31, काठमाडौं, नेपाल]
# 28      [City Center (Kamalpokhari), काठमाडौं, नेपाल]
# 29                                            [नेपाल]
# 30                                            [नेपाल]
# 31                                            [नेपाल]
# 32                                            [नेपाल]
# 33                           [Kathmandu 44600, नेपाल]
# 34                                            [नेपाल]
# 35                   [Khichapokhari, काठमाडौं, नेपाल]
# 36                                  [New Road, नेपाल]
# 37  [Bhagawati Marg (BTWN Thirbum Marg & Sama Marg...
# 38                                            [नेपाल]
# 39                                            [नेपाल]
# 40                   [Thamel, Kathmandu 44600, नेपाल]
# 41                                            [नेपाल]
# 42                   [Thamel, Kathmandu 44600, नेपाल]
# 43              [Jp Road (Chaskibari), Thamel, नेपाल]
# 44                            [काठमाडौं 44600, नेपाल]
# 45                     [J P Marg, カトマンズ 44600, नेपाल]
# 46                                            [नेपाल]
# 47                            [काठमाडौं 44600, नेपाल]
# 48                                            [नेपाल]
# 49        [Ananda Bhawan (Lazimpat), काठमाडौं, नेपाल]
#
#                       crossStreet                        id
# 0                             NaN  5a5615c21b0ea539aaf508db
# 1                 Bhagawati Bahal  54532e2a498e92ceba7d6da4
# 2    Across Naxal Bhagwati Mandir  516e7605e4b0e7ecec8f8751
# 3                             NaN  50e3f741e4b0b92a498527f7
# 4                             NaN  520c59e611d23d6d7c3ccc01
# 5                             NaN  4fa64fece4b0cbe2e0a9467e
# 6                             NaN  537f2e7a498ebe93301f6199
# 7                             NaN  54198c99498e9b142b5934e1
# 8                             NaN  5284913c11d23b71240eaa0a
# 9                             NaN  5853819803cf255eb30375e1
# 10                            NaN  530359b6498ebaab58ded635
# 11                            NaN  52c9601a498eaad42cd93056
# 12                            NaN  5d51387c941303000822e8a3
# 13                            NaN  4f683fc7e4b0d535a5cc886d
# 14           Next To Everest Momo  50c709b7e4b0b353eb63fcf5
# 15                            NaN  59ec94b1a6031c48a4034f70
# 16                            NaN  4eeb13b49a52f269b6ca4bea
# 17                            NaN  51bbf7e2498ed05ef8d6adc0
# 18                            NaN  57398e69498e9e5d0c833d82
# 19                            NaN  539ee1ae498e35589f8bc01d
# 20                            NaN  4f6701e9e4b03a7ce336627f
# 21                            NaN  51729f17e4b0cb9cb448aae4
# 22                            NaN  555c77ac498e63ff961a4613
# 23                            NaN  5c91e9c33e6741002cfa2b39
# 24                            NaN  4eda0df1b6344371f66bbabd
# 25                            NaN  4fa27758e4b0b4ed787228fe
# 26                            NaN  5593a39f498e4e910f31e76c
# 27                            NaN  567e6f09498ed310e2ae3ca1
# 28                   Kamalpokhari  5930fca0396de0394a28f9f0
# 29                            NaN  52ee132f498e5dcea7dee6d7
# 30                            NaN  533ecb7a498ee15d1b17dd91
# 31                            NaN  539aa2db498e718f8995e8d6
# 32                            NaN  56768fa2498e41010315de03
# 33                            NaN  5ad9b87f1cf2e1494231b434
# 34                            NaN  53592917498e7027ec6240dd
# 35                            NaN  50921fd8498eeb726306d104
# 36                            NaN  55096ccf498e9c08e09feede
# 37  BTWN Thirbum Marg & Sama Marg  538d8102498e2e5d44d78282
# 38                            NaN  4f755caee4b05b70741d2a56
# 39                            NaN  52a06d2311d25a833f1457ac
# 40                            NaN  5c5bcd41c21cb1002cb6bfbe
# 41                            NaN  5230677211d22f9e9d7941bf
# 42                            NaN  5ad999eb56c89f7f7a2eab01
# 43                     Chaskibari  5487f5aa498ef11b79747e1b
# 44                            NaN  58283da9da08cb6d4778d234
# 45                            NaN  5b98b968c365880039150ec5
# 46                            NaN  519e24d4498e5da24bf29bcd
# 47                            NaN  58283d229e41df0d62f0ffeb
# 48                            NaN  50c3151ae4b009e3bbb65e93
# 49                       Lazimpat  4edf431077c8c05f362e2317

# %%
dataframe_filtered.name
# Out:
# 0                     Nepal Go - Special Chinese Food
# 1                          R.S. Chinese Food Services
# 2                             Chinese Stick Food Cafe
# 3                       Chinese Friendship Restaurant
# 4                                     Chinese Embassy
# 5                                    Chinese charming
# 6                               Kathmandu Chinese Mee
# 7                                  Chinese Restaurant
# 8                  Garden Park Fast Food & Restaurant
# 9                          Chinese noodle shop / 中华面馆
# 10                                 Chinese Sumai Cafe
# 11                Zhongguo Flavour Chinese Restaurant
# 12        Nepal-Chinese Educational & Cultural Center
# 13                          Best Fast Food Restaurant
# 14                        Chito Mitho Stick Fast Food
# 15                                      Food Junction
# 16                                Nanglo Chinese Room
# 17                                     Wifi Food Cafe
# 18                             Centre Point Food Cafe
# 19                                Brother's Fast Food
# 20                                   Jhakas Fast Food
# 21                    Royal Dragon Chinese Restaurant
# 22                             Delicious Food Station
# 23                       Classic Rock Coffee/Food/Bar
# 24    Bok Choy Chinese, Continental & Italian Cuisine
# 25                  Kathmandu Fast Food & Bakery Cafe
# 26                              New Acharya Fast Food
# 27                  3Brother's Fast Food & Restaurant
# 28                           Food Court (City Center)
# 29                       Dibya Ratna Terai Food Court
# 30          the hygienic panipuri in town & fast food
# 31                                  kwality food cafe
# 32                      Shafqat Halal Food Restaurant
# 33                                         Food Truck
# 34                                 Kantipur Fast Food
# 35                                  Kwality Food Cafe
# 36                        Little Kathmandu Stick Food
# 37                         Fast Food & Newari Kitchen
# 38                            Kwality fast food (KFC)
# 39                  Delicious Food Cafe & Cushion Bar
# 40                  Green Himalaya Coffee & Fast Food
# 41                           Kylin Chinese restaurant
# 42                                  Namaste Fast Food
# 43                                  The Mix Food land
# 44                                            Foodies
# 45                     Sunflower Fast Food Restaurant
# 46                                       New Foodland
# 47                                           Foodie's
# 48                                  Deurali Food Land
# 49                                             Vootoo
# Name: name, dtype: object

# %% [markdown]
# ### Visualization of data of eateries that serves Chinese food in Kathmandu

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# Chinese restaurants as crimson circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='crimson',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
